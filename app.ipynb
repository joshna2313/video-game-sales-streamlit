# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt


st.set_page_config(page_title="Video Game Sales Dashboard", layout="wide")


st.title("Video Game Sales & Ratings Dashboard")

# Load data
@st.cache_data
def load_data():
    df = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016-checkpoint.csv")
    return df

df = load_data()

# Clean column names
df.columns = df.columns.str.lower()

# Basic cleaning
df['user_score'] = df['user_score'].replace('tbd', pd.NA)
df['user_score'] = pd.to_numeric(df['user_score'])
df = df.dropna(subset=['year_of_release', 'global_sales'])
df['year_of_release'] = df['year_of_release'].astype(int)

# Sidebar filters
st.sidebar.header("Filters")

year_range = st.sidebar.slider(
    "Select Year Range",
    int(df['year_of_release'].min()),
    int(df['year_of_release'].max()),
    (2000, 2015)
)

genres = st.sidebar.multiselect(
    "Select Genre(s)",
    options=df['genre'].unique(),
    default=df['genre'].unique()
)
platforms = st.sidebar.multiselect(
    "Select Platform(s)",
    options=df['platform'].unique(),
    default=df['platform'].unique()
)

filtered_df = df[
    (df['year_of_release'] >= year_range[0]) &
    (df['year_of_release'] <= year_range[1]) &
    (df['genre'].isin(genres)) &
    (df['platform'].isin(platforms))
]


# KPI Metrics
st.subheader("Key Metrics")

col1, col2, col3 = st.columns(3)

total_sales = filtered_df['global_sales'].sum()

top_genre = (
    filtered_df.groupby('genre')['global_sales'].sum().idxmax()
    if not filtered_df.empty else "N/A"
)

top_platform = (
    filtered_df.groupby('platform')['global_sales'].sum().idxmax()
    if not filtered_df.empty else "N/A"
)

col1.metric("Total Global Sales (M)", f"{total_sales:.2f}")
col2.metric("Top Genre", top_genre)
col3.metric("Top Platform", top_platform)

st.subheader(" Sales Overview")

col1, col2 = st.columns(2)


# ---- Chart 1: Sales over time ----
with col1:
    st.markdown(" Global Sales Over Time")

    sales_by_year = (
        filtered_df
        .groupby('year_of_release')['global_sales']
        .sum()
        .reset_index()
    )

    fig1, ax1 = plt.subplots()
    ax1.plot(
        sales_by_year['year_of_release'],
        sales_by_year['global_sales'],
        color='steelblue'
    )
    ax1.set_xlabel("Year")
    ax1.set_ylabel("Global Sales (M)")
    st.pyplot(fig1)

# ---- Chart 2: Sales by Genre ----
with col2:
    st.markdown("Sales by Genre")

    genre_sales = (
        filtered_df
        .groupby('genre')['global_sales']
        .sum()
        .sort_values(ascending=False)
    )

    fig2, ax2 = plt.subplots()
    ax2.bar(
        genre_sales.index,
        genre_sales.values,
        color='teal'
    )
    ax2.set_xlabel("Genre")
    ax2.set_ylabel("Global Sales (M)")
    plt.xticks(rotation=45)
    st.pyplot(fig2)


# Chart 3: Critic Score vs Sales
st.subheader("Critic Score vs Global Sales")

fig3, ax3 = plt.subplots()
ax3.scatter(
    filtered_df['critic_score'],
    filtered_df['global_sales'],
    alpha=0.6,
    color='purple'
)
ax3.set_xlabel("Critic Score")
ax3.set_ylabel("Global Sales")
st.pyplot(fig3)

st.subheader("Top 10 Games by Global Sales")

top_games = (
    filtered_df
    .groupby('name')['global_sales']
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

st.dataframe(top_games)


# Footer
st.markdown("---")
st.markdown("**Data Source:** Kaggle – Video Game Sales with Ratings")
# Out:
# 2026-01-28 11:36:11.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.712 No runtime found, using MemoryCacheStorageManager
# 2026-01-28 11:36:11.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:11.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-28 11:36:12.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
